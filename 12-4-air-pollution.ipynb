# %%
# ORIGINAL SOURCE:
# https://www.americashealthrankings.org/explore/annual/measure/air/state/ALL
# 2013

# %%
# AIR POLLUTION:
# https://www.americashealthrankings.org/about/methodology/data-sources-and-measures

# Air pollution is based upon the Environmental Protection Agency (EPA) 
# annual estimate of PM2.5 in each county weighted by the population of 
# that county. For counties without an estimated exposure, the lowest estimated
# exposure for the Air Quality Control Region is used. If the county still 
# does not have an estimate, the minimum state value is used for the county. 
# Air pollution is calculated using the most recent three years of data 
# available.


# PM2.5 (via Google):
# "PM2.5 refers to atmospheric particulate matter (PM)
# that have a diameter of less than 2.5 micrometers"

# %%
# RANKING METHODS:
# https://www.americashealthrankings.org/about/methodology/rankings

# %%
import pandas as pd

df = pd.read_csv('/Users/flatironschool/Downloads/2013-Annual.csv')

# %%
output = df[['State Name', 'Value']]

# %%
final = output.drop([50])

# %%
final
# Out:
#               State Name  Value
# 0                Alabama   10.7
# 1                 Alaska    5.4
# 2                Arizona    9.6
# 3               Arkansas   10.7
# 4             California   15.1
# 5               Colorado    6.7
# 6            Connecticut    9.0
# 7               Delaware   10.6
# 8                Florida    7.6
# 9                Georgia   11.2
# 10                Hawaii    9.1
# 11                 Idaho    8.6
# 12              Illinois   11.7
# 13               Indiana   12.6
# 14                  Iowa    9.9
# 15                Kansas    8.9
# 16              Kentucky   11.1
# 17             Louisiana    9.6
# 18                 Maine    7.5
# 19              Maryland   10.8
# 20         Massachusetts    8.1
# 21              Michigan    9.3
# 22             Minnesota    8.1
# 23           Mississippi    9.8
# 24              Missouri   10.0
# 25               Montana    7.2
# 26              Nebraska    8.2
# 27                Nevada    9.1
# ...
