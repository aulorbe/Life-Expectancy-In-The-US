# %%
import pandas as pd

df_july = pd.read_excel('/Users/flatironschool/Downloads/SNAP_zip/JUL 2010.xls', header=None)
df_jan = pd.read_excel('/Users/flatironschool/Downloads/SNAP_zip/Jan 2010.xls', header=None)

# %%
# CLEANING JANUARY TABLE

# %%
jan = df_jan.iloc[4:].drop(columns=[2,4,6,7,8,9,10,11,12,13]).dropna()
jan.columns = ['County Info', 'SNAP Public Assistance Participation', 'SNAP Non-Public Assistance Participation', 'Total SNAP PA and Non-PA']

# %%
cleaned_counties = []
for county in jan['County Info']:
    county = county[8:11] + county[15:]
    cleaned_counties.append(county)

# %%
jan['new county info'] = cleaned_counties

# %%
states = []
for county in jan['new county info']: 
    states.append(county[:3].strip())
    
jan['States'] = states

# %%
just_counties = []
for county in jan['new county info']: 
    just_counties.append(county[3:])
    
jan['Counties'] = just_counties

# %%
jan = jan.reset_index(drop=True)
jan.drop(columns=['new county info', 'County Info'])
# Out:
#      SNAP Public Assistance Participation  \
# 0                                     838
# 1                                    1565
# 2                                    1096
# 3                                     613
# 4                                    1062
# 5                                     612
# 6                                     895
# 7                                    3536
# 8                                    1239
# 9                                     694
# 10                                   1164
# 11                                    502
# 12                                   1146
# 13                                    275
# 14                                    304
# 15                                    757
# 16                                   1163
# 17                                    657
# 18                                    295
# 19                                    960
# 20                                    509
# 21                                   1418
# 22                                   1586
# 23                                   3529
# 24                                   1193
# 25                                   1446
# 26                                   1126
# 27                                   2244
# 28                                    715
# 29                                    806
# ...                                   ...
# 2523                                 2215
# 2524                                  217
# 2525                                 1764
# 2526                                  157
# 2527                                  189
# 2528                                  352
# 2529                                  160
# 2530                                  268
# 2531                                  696
# 2532                                  138
# 2533                                  161
# 2534                                  181
# 2535                                  121
# 2536                                  403
# 2537                                  174
# 2538                                  333
# 2539                                  725
# 2540                                  303
# 2541                                  194
# 2542                                  990
# 2543                                  618
# 2544                                   91
# 2545                                    7
# 2546                                   33
# 2547                                   11
# 2548                                   44
# 2549                                   13
# 2550                                    2
# 2551                                  668
# 2552                              7780104
#
#      SNAP Non-Public Assistance Participation Total SNAP PA and Non-PA States  \
# 0                                        6129                     6967     AL
# 1                                       16476                    18041     AL
# 2                                        4943                     6039     AL
# 3                                        3132                     3745     AL
# 4                                        6970                     8032     AL
# 5                                        2160                     2772     AL
# 6                                        4198                     5093     AL
# 7                                       20060                    23596     AL
# 8                                        6696                     7935     AL
# 9                                        4196                     4890     AL
# 10                                       7961                     9125     AL
# 11                                       2680                     3182     AL
# 12                                       4720                     5866     AL
# 13                                       1770                     2045     AL
# 14                                       2017                     2321     AL
# 15                                       4836                     5593     AL
# 16                                       7472                     8635     AL
# 17                                       3520                     4177     AL
# 18                                       1725                     2020     AL
# 19                                       6601                     7561     AL
# 20                                       2293                     2802     AL
# 21                                       9408                    10826     AL
# 22                                       8266                     9852     AL
# 23                                      12596                    16125     AL
# 24                                      10904                    12097     AL
# 25                                       8840                    10286     AL
# 26                                       7803                     8929     AL
# 27                                      14141                    16385     AL
# 28                                       2934                     3649     AL
# 29                                       5241                     6047     AL
# ...                                       ...                      ...    ...
# 2552
#
# [2553 rows x 5 columns]

# %%
# CLEANING JULY SNAP TABLE

# %%
july = df_july.iloc[4:].drop(columns=[2,4,6,7,8,9,10,11,12,13]).dropna()
july.columns = ['County Info', 'SNAP Public Assistance Participation', 'SNAP Non-Public Assistance Participation', 'Total SNAP PA and Non-PA']

cleaned_counties = []
for county in july['County Info']:
    county = county[8:11] + county[15:]
    cleaned_counties.append(county)
    
july['new county info'] = cleaned_counties 
    
states = []
for county in july['new county info']: 
    states.append(county[:3].strip())
    
july['States'] = states

just_counties = []
for county in july['new county info']: 
    just_counties.append(county[3:])
    
july['Counties'] = just_counties

july = july.reset_index(drop=True)
july.drop(columns=['new county info', 'County Info'])
# Out:
#      SNAP Public Assistance Participation  \
# 0                                     868
# 1                                    1671
# 2                                    1041
# 3                                     582
# 4                                     984
# 5                                     577
# 6                                     871
# 7                                    3670
# 8                                    1270
# 9                                     728
# 10                                   1107
# 11                                    503
# 12                                   1235
# 13                                    292
# 14                                    322
# 15                                    669
# 16                                   1196
# 17                                    627
# 18                                    287
# 19                                    872
# 20                                    436
# 21                                   1351
# 22                                   1518
# 23                                   3395
# 24                                   1262
# 25                                   1402
# 26                                   1119
# 27                                   2202
# 28                                    712
# 29                                    850
# ...                                   ...
# 2572                                 2267
# 2573                                  194
# 2574                                 1737
# 2575                                  161
# 2576                                  211
# 2577                                  348
# 2578                                  147
# 2579                                  253
# 2580                                  675
# 2581                                  128
# 2582                                  145
# 2583                                  195
# 2584                                  117
# 2585                                  420
# 2586                                  174
# 2587                                  348
# 2588                                  749
# 2589                                  309
# 2590                                  184
# 2591                                  969
# 2592                                  609
# 2593                                  104
# 2594                                   11
# 2595                                   29
# 2596                                    8
# 2597                                   63
# 2598                                   13
# 2599                                    2
# 2600                                  613
# 2601                              8162142
#
#      SNAP Non-Public Assistance Participation Total SNAP PA and Non-PA States  \
# 0                                        6270                     7138     AL
# 1                                       17697                    19368     AL
# 2                                        4904                     5945     AL
# 3                                        3321                     3903     AL
# 4                                        7445                     8429     AL
# 5                                        2280                     2857     AL
# 6                                        4207                     5078     AL
# 7                                       20067                    23737     AL
# 8                                        6709                     7979     AL
# 9                                        4393                     5121     AL
# 10                                       8257                     9364     AL
# 11                                       2659                     3162     AL
# 12                                       4753                     5988     AL
# 13                                       1840                     2132     AL
# 14                                       2162                     2484     AL
# 15                                       5324                     5993     AL
# 16                                       7657                     8853     AL
# 17                                       3493                     4120     AL
# 18                                       1634                     1921     AL
# 19                                       6808                     7680     AL
# 20                                       2448                     2884     AL
# 21                                       9710                    11061     AL
# 22                                       8356                     9874     AL
# 23                                      13145                    16540     AL
# 24                                      11600                    12862     AL
# 25                                       9537                    10939     AL
# 26                                       7995                     9114     AL
# 27                                      14728                    16930     AL
# 28                                       3043                     3755     AL
# 29                                       5453                     6303     AL
# ...                                       ...                      ...    ...
# 2572                                    25489                    27756     WI
# 2573                                     2316                     2510     WI
# 2574                                    22950                    24687     WI
# 2575                                     2410                     2571     WI
# 2576                                     5206                     5417     WI
# 2577                                     6037                     6385     WI
# 2578                                     2907                     3054     WI
# 2579                                     4017                     4270     WI
# 2580                                    11176                    11851     WI
# 2581                                     2258                     2386     WI
# 2582                                     2698                     2843     WI
# 2583                                     2647                     2842     WI
# 2584                                     1713                     1830     WI
# 2585                                    10108                    10528     WI
# 2586                                     2378                     2552     WI
# 2587                                     7632                     7980     WI
# 2588                                    13355                    14104     WI
# 2589                                     4711                     5020     WI
# 2590                                     2708                     2892     WI
# 2591                                    13785                    14754     WI
# 2592                                     8676                     9285     WI
# 2593                                     2226                     2330     WI
# 2594                                      215                      226     WI
# 2595                                      569                      598     WI
# 2596                                      473                      481     WI
# 2597                                     1280                     1343     WI
# 2598                                      216                      229     WI
# 2599                                       65                       67     WI
# 2600                                    34706                    35319     WY
# 2601                                 33656178                 41818320    mar
#
#                     Counties
# 0          AUTAUGA CO FS OFF
# 1          BALDWIN CO FS OFF
# 2          BARBOUR CO FS OFF
# 3             BIBB CO FS OFF
# 4           BLOUNT CO FS OFF
# 5          BULLOCK CO FS OFF
# 6              BUTLER CO FSO
# 7          CALHOUN CO FS OFF
# 8         CHAMBERS CO FS OFF
# 9      CHEROKEE CO FS OFFICE
# 10         CHILTON CO FS OFF
# 11         CHOCTAW CO FS OFF
# 12         CLARKE CO FS OFF.
# 13            CLAY CO FS OFF
# 14        CLEBURNE CO FS OFF
# 15          COFFEE CO FS OFF
# 16         COLBERT CO FS OFF
# 17         CONECUH CO FS OFF
# 18              COOSA CO FSO
# 19       COVINGTON CO FS OFF
# 20           CRENSHAW CO FSO
# 21         CULLMAN CO FS OFF
# 22            DALE CO FS OFF
# 23          DALLAS CO FS OFF
# 24          DEKALB CO FS OFF
# 25          ELMORE CO FS OFF
# 26        ESCAMBIA CO FS OFF
# 27          ETOWQH CO FS OFF
# 28         FAYETTE CO FS OFF
# 29        FRANKLIN CO FS OFF
# ...                      ...
# 2572           RACINE CO DSS
# 2573         RICHLAND CO DSS
# 2574             ROCK CO DSS
# 2575             RUSK CO DSS
# 2576         ST CROIX CO DSS
# 2577             SAUK CO DSS
# 2578           SAWYER CO DSS
# 2579          SHAWANO CO DSS
# 2580        SHEBOYGAN CO DSS
# 2581           TAYLOR CO DSS
# 2582      TREMPEALEAU CO DSS
# 2583           VERNON CO DSS
# 2584            VILAS CO DSS
# 2585         WALWORTH CO DSS
# 2586         WASHBURN CO DSS
# 2587       WASHINGTON CO DSS
# 2588         WAUKESHA CO DSS
# 2589          WAUPACA CO DSS
# 2590         WAUSHARA CO DSS
# 2591        WINNEBAGO CO DSS
# 2592             WOOD CO DSS
# 2593   ONEIDA TRIBAL COUNCIL
# 2594  STOCKBRIDGE-MUNSEE TRI
# 2595  RED CLIFF TRIBAL COUNC
# 2596  BAD RIVER TRIBAL COUNC
# 2597  LAC DU FLAMBEAU TRIBAL
# 2598  SOKAOGON TRIBAL AGENCY
# 2599        POTAWATOMI TRIBE
# 2600         WYOMING SD PASS
# 2601
#
# [2602 rows x 5 columns]

# %%
# COMBINING JAN AND JULY TABLES

# %%
merged = pd.merge(jan,july, on='Counties')

merged['Jan & July Public Assist. Participation'] = merged['SNAP Public Assistance Participation_x'] + merged['SNAP Public Assistance Participation_y']

merged['Jan & July Non-Public Assist. Participation'] = merged['SNAP Non-Public Assistance Participation_x'] + merged['SNAP Non-Public Assistance Participation_y']

merged['Jan & July TOTAL Assist. Participation'] = merged['Total SNAP PA and Non-PA_x'] +  merged['Total SNAP PA and Non-PA_y']

something = merged.drop(columns=['County Info_x', 'County Info_y', 'new county info_x', 'States_x', 'new county info_y', 'Total SNAP PA and Non-PA_y', 'SNAP Non-Public Assistance Participation_y', 'SNAP Public Assistance Participation_y', 'Total SNAP PA and Non-PA_x',  'SNAP Non-Public Assistance Participation_x', 'SNAP Public Assistance Participation_x'])

something.rename(columns = {'States_y':'States'})

final = something.drop(something.index[3444])

final
# Out:
#                     Counties States_y Jan & July Public Assist. Participation  \
# 0          AUTAUGA CO FS OFF       AL                                    1706
# 1          BALDWIN CO FS OFF       AL                                    3236
# 2          BARBOUR CO FS OFF       AL                                    2137
# 3             BIBB CO FS OFF       AL                                    1195
# 4           BLOUNT CO FS OFF       AL                                    2046
# 5          BULLOCK CO FS OFF       AL                                    1189
# 6              BUTLER CO FSO       AL                                    1766
# 7          CALHOUN CO FS OFF       AL                                    7206
# 8         CHAMBERS CO FS OFF       AL                                    2509
# 9      CHEROKEE CO FS OFFICE       AL                                    1422
# 10         CHILTON CO FS OFF       AL                                    2271
# 11         CHOCTAW CO FS OFF       AL                                    1005
# 12         CLARKE CO FS OFF.       AL                                    2381
# 13            CLAY CO FS OFF       AL                                     567
# 14        CLEBURNE CO FS OFF       AL                                     626
# 15          COFFEE CO FS OFF       AL                                    1426
# 16         COLBERT CO FS OFF       AL                                    2359
# 17         CONECUH CO FS OFF       AL                                    1284
# 18              COOSA CO FSO       AL                                     582
# 19       COVINGTON CO FS OFF       AL                                    1832
# 20           CRENSHAW CO FSO       AL                                     945
# 21         CULLMAN CO FS OFF       AL                                    2769
# 22            DALE CO FS OFF       AL                                    3104
# 23          DALLAS CO FS OFF       AL                                    6924
# 24          DEKALB CO FS OFF       AL                                    2455
# 25          ELMORE CO FS OFF       AL                                    2848
# 26        ESCAMBIA CO FS OFF       AL                                    2245
# 27          ETOWQH CO FS OFF       AL                                    4446
# 28         FAYETTE CO FS OFF       AL                                    1427
# 29        FRANKLIN CO FS OFF       AL                                    1656
# ...                      ...      ...                                     ...
# 3414          PORTAGE CO DSS       WI                                     659
# 3415            PRICE CO DSS       WI                                     286
# 3416           RACINE CO DSS       WI                                    4482
# 3417         RICHLAND CO DSS       WI                                     411
# 3418             ROCK CO DSS       WI                                    3501
# 3419             RUSK CO DSS       WI                                     318
# 3420         ST CROIX CO DSS       WI                                     400
# 3421             SAUK CO DSS       WI                                     700
# 3422           SAWYER CO DSS       WI                                     307
# 3423          SHAWANO CO DSS       WI                                     521
# 3424        SHEBOYGAN CO DSS       WI                                    1371
# 3425           TAYLOR CO DSS       WI                                     266
# 3426      TREMPEALEAU CO DSS       WI                                     306
# 3427           VERNON CO DSS       WI                                     376
# 3428            VILAS CO DSS       WI                                     238
# 3429         WALWORTH CO DSS       WI                                     823
# 3430         WASHBURN CO DSS       WI                                     348
# %%
# dropping all SNAP data except for total number because others seem superfluous
final = final.drop(columns=['Jan & July Public Assist. Participation', 'Jan & July Non-Public Assist. Participation'])

# %%
# renaming total SNAP feature to 'Total SNAP' for legibility
final = final.rename(columns={'Jan & July TOTAL Assist. Participation': 'Total SNAP', 'States_y': 'States'})

# %%
# viewing final
final
# Out:
#                     Counties States Total SNAP
# 0          AUTAUGA CO FS OFF     AL      14105
# 1          BALDWIN CO FS OFF     AL      37409
# 2          BARBOUR CO FS OFF     AL      11984
# 3             BIBB CO FS OFF     AL       7648
# 4           BLOUNT CO FS OFF     AL      16461
# 5          BULLOCK CO FS OFF     AL       5629
# 6              BUTLER CO FSO     AL      10171
# 7          CALHOUN CO FS OFF     AL      47333
# 8         CHAMBERS CO FS OFF     AL      15914
# 9      CHEROKEE CO FS OFFICE     AL      10011
# 10         CHILTON CO FS OFF     AL      18489
# 11         CHOCTAW CO FS OFF     AL       6344
# 12         CLARKE CO FS OFF.     AL      11854
# 13            CLAY CO FS OFF     AL       4177
# 14        CLEBURNE CO FS OFF     AL       4805
# 15          COFFEE CO FS OFF     AL      11586
# 16         COLBERT CO FS OFF     AL      17488
# 17         CONECUH CO FS OFF     AL       8297
# 18              COOSA CO FSO     AL       3941
# 19       COVINGTON CO FS OFF     AL      15241
# 20           CRENSHAW CO FSO     AL       5686
# 21         CULLMAN CO FS OFF     AL      21887
# 22            DALE CO FS OFF     AL      19726
# 23          DALLAS CO FS OFF     AL      32665
# 24          DEKALB CO FS OFF     AL      24959
# 25          ELMORE CO FS OFF     AL      21225
# 26        ESCAMBIA CO FS OFF     AL      18043
# 27          ETOWQH CO FS OFF     AL      33315
# 28         FAYETTE CO FS OFF     AL       7404
# 29        FRANKLIN CO FS OFF     AL      12350
# ...                      ...    ...        ...
# 3414          PORTAGE CO DSS     WI      12327
# 3415            PRICE CO DSS     WI       3730
# 3416           RACINE CO DSS     WI      57114
# 3417         RICHLAND CO DSS     WI       5110
# 3418             ROCK CO DSS     WI      50776
# 3419             RUSK CO DSS     WI       5335
# 3420         ST CROIX CO DSS     WI      10887
# 3421             SAUK CO DSS     WI      12835
# 3422           SAWYER CO DSS     WI       6360
# 3423          SHAWANO CO DSS     WI       8766
# 3424        SHEBOYGAN CO DSS     WI      24034
# 3425           TAYLOR CO DSS     WI       4844
# 3426      TREMPEALEAU CO DSS     WI       5762
# 3427           VERNON CO DSS     WI       5760
# 3428            VILAS CO DSS     WI       3744
# 3429         WALWORTH CO DSS     WI      21095
# 3430         WASHBURN CO DSS     WI       5214
# 3431         WAUKESHA CO DSS     WI      28157
# 3432          WAUPACA CO DSS     WI      10141
# 3433         WAUSHARA CO DSS     WI       5947
# 3434        WINNEBAGO CO DSS     WI      30220
# 3435             WOOD CO DSS     WI      18757
# 3436   ONEIDA TRIBAL COUNCIL     WI       4818
# 3437  STOCKBRIDGE-MUNSEE TRI     WI        458
# 3438  RED CLIFF TRIBAL COUNC     WI       1215
# 3439  BAD RIVER TRIBAL COUNC     WI       1078
# 3440  LAC DU FLAMBEAU TRIBAL     WI       2718
# 3441  SOKAOGON TRIBAL AGENCY     WI        458
# 3442        POTAWATOMI TRIBE     WI        144
# 3443         WYOMING SD PASS     WY      69813
#
# [3444 rows x 3 columns]

# %%
# getting dictionary of states in order to turn state abbreviations into full state names
# states dictionary from http://code.activestate.com/recipes/577305-python-dictionary-of-us-states-and-territories/

states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'}

# %%
# looping through dataframe and making list of all state names

states_list = []

for i in final['States']: 
    if i in states: 
        st = states[i]
        states_list.append(st)
        
states_list
# Out:
# ['Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Kansas',
#  'Arizona',
#  'Kansas',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'New Mexico',
#  'Arizona',
#  'New Mexico',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arizona',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Nevada',
#  'Arkansas',
#  'Nevada',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Oklahoma',
#  'Arkansas',
#  'Oklahoma',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Nevada',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Nevada',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Nevada',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Nevada',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Arkansas',
#  'Oklahoma',
#  'Arkansas',
#  'Oklahoma',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'New Mexico',
#  'Arkansas',
#  'New Mexico',
#  'Arkansas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Oklahoma',
#  'Texas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'Arkansas',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Michigan',
#  'Colorado',
#  'Michigan',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Illinois',
#  'Kansas',
#  'Colorado',
#  'Illinois',
#  'Kansas',
#  'Colorado',
#  'Illinois',
#  'Kansas',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Michigan',
#  'Colorado',
#  'Michigan',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'Colorado',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Wisconsin',
#  'Colorado',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Delaware',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Florida',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'New Jersey',
#  'North Carolina',
#  'Georgia',
#  'New Jersey',
#  'North Carolina',
#  'Georgia',
#  'New Jersey',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Tennessee',
#  'Georgia',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Kansas',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kansas',
#  'Kentucky',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Illinois',
#  'Kentucky',
#  'North Carolina',
#  'Tennessee',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'Kentucky',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'North Carolina',
#  'Georgia',
#  'Georgia',
#  'Guam',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  'Hawaii',
#  ...]

# %%
# making Full State Name column in dataframe to hold full state names 
# dropping old States column that had only the state abbreviations

final['Full State Name'] = states_list
final = final.drop(columns=['States'])
final
# Out:
#                     Counties Total SNAP Full State Name
# 0          AUTAUGA CO FS OFF      14105         Alabama
# 1          BALDWIN CO FS OFF      37409         Alabama
# 2          BARBOUR CO FS OFF      11984         Alabama
# 3             BIBB CO FS OFF       7648         Alabama
# 4           BLOUNT CO FS OFF      16461         Alabama
# 5          BULLOCK CO FS OFF       5629         Alabama
# 6              BUTLER CO FSO      10171         Alabama
# 7          CALHOUN CO FS OFF      47333         Alabama
# 8         CHAMBERS CO FS OFF      15914         Alabama
# 9      CHEROKEE CO FS OFFICE      10011         Alabama
# 10         CHILTON CO FS OFF      18489         Alabama
# 11         CHOCTAW CO FS OFF       6344         Alabama
# 12         CLARKE CO FS OFF.      11854         Alabama
# 13            CLAY CO FS OFF       4177         Alabama
# 14        CLEBURNE CO FS OFF       4805         Alabama
# 15          COFFEE CO FS OFF      11586         Alabama
# 16         COLBERT CO FS OFF      17488         Alabama
# 17         CONECUH CO FS OFF       8297         Alabama
# 18              COOSA CO FSO       3941         Alabama
# 19       COVINGTON CO FS OFF      15241         Alabama
# 20           CRENSHAW CO FSO       5686         Alabama
# 21         CULLMAN CO FS OFF      21887         Alabama
# 22            DALE CO FS OFF      19726         Alabama
# 23          DALLAS CO FS OFF      32665         Alabama
# 24          DEKALB CO FS OFF      24959         Alabama
# 25          ELMORE CO FS OFF      21225         Alabama
# 26        ESCAMBIA CO FS OFF      18043         Alabama
# 27          ETOWQH CO FS OFF      33315         Alabama
# 28         FAYETTE CO FS OFF       7404         Alabama
# 29        FRANKLIN CO FS OFF      12350         Alabama
# ...                      ...        ...             ...
# 3414          PORTAGE CO DSS      12327       Wisconsin
# 3415            PRICE CO DSS       3730       Wisconsin
# 3416           RACINE CO DSS      57114       Wisconsin
# 3417         RICHLAND CO DSS       5110       Wisconsin
# 3418             ROCK CO DSS      50776       Wisconsin
# 3419             RUSK CO DSS       5335       Wisconsin
# 3420         ST CROIX CO DSS      10887       Wisconsin
# 3421             SAUK CO DSS      12835       Wisconsin
# 3422           SAWYER CO DSS       6360       Wisconsin
# 3423          SHAWANO CO DSS       8766       Wisconsin
# 3424        SHEBOYGAN CO DSS      24034       Wisconsin
# 3425           TAYLOR CO DSS       4844       Wisconsin
# 3426      TREMPEALEAU CO DSS       5762       Wisconsin
# 3427           VERNON CO DSS       5760       Wisconsin
# 3428            VILAS CO DSS       3744       Wisconsin
# 3429         WALWORTH CO DSS      21095       Wisconsin
# 3430         WASHBURN CO DSS       5214       Wisconsin
# 3431         WAUKESHA CO DSS      28157       Wisconsin
# 3432          WAUPACA CO DSS      10141       Wisconsin
# 3433         WAUSHARA CO DSS       5947       Wisconsin
# 3434        WINNEBAGO CO DSS      30220       Wisconsin
# 3435             WOOD CO DSS      18757       Wisconsin
# 3436   ONEIDA TRIBAL COUNCIL       4818       Wisconsin
# 3437  STOCKBRIDGE-MUNSEE TRI        458       Wisconsin
# 3438  RED CLIFF TRIBAL COUNC       1215       Wisconsin
# 3439  BAD RIVER TRIBAL COUNC       1078       Wisconsin
# 3440  LAC DU FLAMBEAU TRIBAL       2718       Wisconsin
# 3441  SOKAOGON TRIBAL AGENCY        458       Wisconsin
# 3442        POTAWATOMI TRIBE        144       Wisconsin
# 3443         WYOMING SD PASS      69813         Wyoming
#
# [3444 rows x 3 columns]

# %%
# cleaning up the county names so that I can match them with the counties we have in the life expectancy dataframe

output = []
for i in final['Counties']:
    just_county_name = i.split(' CO ')[:1]
    output.extend(just_county_name)
    
final['Split Counties'] = output

final = final.drop(columns=['Counties'])
final
# Out:
#      Total SNAP Full State Name          Split Counties
# 0         14105         Alabama                 AUTAUGA
# 1         37409         Alabama                 BALDWIN
# 2         11984         Alabama                 BARBOUR
# 3          7648         Alabama                    BIBB
# 4         16461         Alabama                  BLOUNT
# 5          5629         Alabama                 BULLOCK
# 6         10171         Alabama                  BUTLER
# 7         47333         Alabama                 CALHOUN
# 8         15914         Alabama                CHAMBERS
# 9         10011         Alabama                CHEROKEE
# 10        18489         Alabama                 CHILTON
# 11         6344         Alabama                 CHOCTAW
# 12        11854         Alabama                  CLARKE
# 13         4177         Alabama                    CLAY
# 14         4805         Alabama                CLEBURNE
# 15        11586         Alabama                  COFFEE
# 16        17488         Alabama                 COLBERT
# 17         8297         Alabama                 CONECUH
# 18         3941         Alabama                   COOSA
# 19        15241         Alabama               COVINGTON
# 20         5686         Alabama                CRENSHAW
# 21        21887         Alabama                 CULLMAN
# 22        19726         Alabama                    DALE
# 23        32665         Alabama                  DALLAS
# 24        24959         Alabama                  DEKALB
# 25        21225         Alabama                  ELMORE
# 26        18043         Alabama                ESCAMBIA
# 27        33315         Alabama                  ETOWQH
# 28         7404         Alabama                 FAYETTE
# 29        12350         Alabama                FRANKLIN
# ...         ...             ...                     ...
# 3414      12327       Wisconsin                 PORTAGE
# 3415       3730       Wisconsin                   PRICE
# 3416      57114       Wisconsin                  RACINE
# 3417       5110       Wisconsin                RICHLAND
# 3418      50776       Wisconsin                    ROCK
# 3419       5335       Wisconsin                    RUSK
# 3420      10887       Wisconsin                ST CROIX
# 3421      12835       Wisconsin                    SAUK
# 3422       6360       Wisconsin                  SAWYER
# 3423       8766       Wisconsin                 SHAWANO
# 3424      24034       Wisconsin               SHEBOYGAN
# 3425       4844       Wisconsin                  TAYLOR
# 3426       5762       Wisconsin             TREMPEALEAU
# 3427       5760       Wisconsin                  VERNON
# 3428       3744       Wisconsin                   VILAS
# 3429      21095       Wisconsin                WALWORTH
# 3430       5214       Wisconsin                WASHBURN
# 3431      28157       Wisconsin                WAUKESHA
# 3432      10141       Wisconsin                 WAUPACA
# 3433       5947       Wisconsin                WAUSHARA
# 3434      30220       Wisconsin               WINNEBAGO
# 3435      18757       Wisconsin                    WOOD
# 3436       4818       Wisconsin   ONEIDA TRIBAL COUNCIL
# 3437        458       Wisconsin  STOCKBRIDGE-MUNSEE TRI
# 3438       1215       Wisconsin  RED CLIFF TRIBAL COUNC
# 3439       1078       Wisconsin  BAD RIVER TRIBAL COUNC
# 3440       2718       Wisconsin  LAC DU FLAMBEAU TRIBAL
# 3441        458       Wisconsin  SOKAOGON TRIBAL AGENCY
# 3442        144       Wisconsin        POTAWATOMI TRIBE
# 3443      69813         Wyoming         WYOMING SD PASS
#
# [3444 rows x 3 columns]

# %%
# importing/cleaning life expectancy csv in order to get list of counties we're working with

counties = pd.read_csv('/Users/flatironschool/Flatiron_Projects/life-expectancy/new_copy_of_repo/module_two_project/csv_files/life_expectancy_data_county.csv', header=None)
counties = counties.rename(columns={0:'Counties', 1:'State', 2: 'Life Expectancy'})
counties = counties.drop(counties.index[0])

# turning all county names in county dataframe uppercase so that they match the SNAP dataframe for easier pairing
counties['Uppercase Counties'] = [i.upper() for i in counties['Counties']]

# resetting index to start at 0
counties = counties.reset_index(drop=True)

# %%
counties.head()
# Out:
#          Counties     State Life Expectancy Uppercase Counties
# 0  Autauga County   Alabama           75.74     AUTAUGA COUNTY
# 1  Baldwin County   Alabama           77.80     BALDWIN COUNTY
# 2  Barbour County   Alabama           75.34     BARBOUR COUNTY
# 3     Bibb County   Alabama           74.13        BIBB COUNTY
# 4   Blount County   Alabama           76.41      BLOUNT COUNTY

# %%
counties.columns
# Out:
# Index(['Counties', 'State', 'Life Expectancy', 'Uppercase Counties'], dtype='object')

# %%
def county_handler(x):
    words = x.split()[:-1]
    y = ''
    for word in words:
        y += (word + ' ')
    return y.strip()

# %%
counties['c'] = counties['Uppercase Counties'].apply(lambda x: county_handler(x))

# %%
counties.head()
# Out:
#          Counties     State Life Expectancy Uppercase Counties        c
# 0  Autauga County   Alabama           75.74     AUTAUGA COUNTY  AUTAUGA
# 1  Baldwin County   Alabama           77.80     BALDWIN COUNTY  BALDWIN
# 2  Barbour County   Alabama           75.34     BARBOUR COUNTY  BARBOUR
# 3     Bibb County   Alabama           74.13        BIBB COUNTY     BIBB
# 4   Blount County   Alabama           76.41      BLOUNT COUNTY   BLOUNT

# %%
print(final.shape)
print(counties.shape)
# Out:
# (3444, 3)
# (3142, 5)

# %%
final.head()
# Out:
#   Total SNAP Full State Name Split Counties
# 0      14105         Alabama        AUTAUGA
# 1      37409         Alabama        BALDWIN
# 2      11984         Alabama        BARBOUR
# 3       7648         Alabama           BIBB
# 4      16461         Alabama         BLOUNT

# %%
counties.head()
# Out:
#          Counties     State Life Expectancy Uppercase Counties        c
# 0  Autauga County   Alabama           75.74     AUTAUGA COUNTY  AUTAUGA
# 1  Baldwin County   Alabama           77.80     BALDWIN COUNTY  BALDWIN
# 2  Barbour County   Alabama           75.34     BARBOUR COUNTY  BARBOUR
# 3     Bibb County   Alabama           74.13        BIBB COUNTY     BIBB
# 4   Blount County   Alabama           76.41      BLOUNT COUNTY   BLOUNT

# %%
final.iloc[0]['Split Counties'] == counties.iloc[0]['c']
# Out:
# True

# %%
# counties.iloc[0]['state_county']

# %%
final['CountyState'] = final['Split Counties'] + ' ' + final['Full State Name']  
counties['CountyState'] =  counties['c'] + counties['State']

# %%
counties
# Out:
#                 Counties       State Life Expectancy  Uppercase Counties  \
# 0         Autauga County     Alabama           75.74      AUTAUGA COUNTY
# 1         Baldwin County     Alabama           77.80      BALDWIN COUNTY
# 2         Barbour County     Alabama           75.34      BARBOUR COUNTY
# 3            Bibb County     Alabama           74.13         BIBB COUNTY
# 4          Blount County     Alabama           76.41       BLOUNT COUNTY
# 5         Bullock County     Alabama           73.61      BULLOCK COUNTY
# 6          Butler County     Alabama           73.63       BUTLER COUNTY
# 7         Calhoun County     Alabama           74.11      CALHOUN COUNTY
# 8        Chambers County     Alabama           74.09     CHAMBERS COUNTY
# 9        Cherokee County     Alabama           75.26     CHEROKEE COUNTY
# 10        Chilton County     Alabama           74.50      CHILTON COUNTY
# 11        Choctaw County     Alabama           75.19      CHOCTAW COUNTY
# 12         Clarke County     Alabama           75.29       CLARKE COUNTY
# 13           Clay County     Alabama           75.25         CLAY COUNTY
# 14       Cleburne County     Alabama           74.53     CLEBURNE COUNTY
# 4          BLOUNT        BLOUNT Alabama
# 5         BULLOCK       BULLOCK Alabama
# 6          BUTLER        BUTLER Alabama
# 7         CALHOUN       CALHOUN Alabama
# 8        CHAMBERS      CHAMBERS Alabama
# 9        CHEROKEE      CHEROKEE Alabama
# 10        CHILTON       CHILTON Alabama
# 11        CHOCTAW       CHOCTAW Alabama
# 12         CLARKE        CLARKE Alabama
# 13           CLAY          CLAY Alabama
# 14       CLEBURNE      CLEBURNE Alabama
# 15         COFFEE        COFFEE Alabama
# 16        COLBERT       COLBERT Alabama
# 17        CONECUH       CONECUH Alabama
# 18          COOSA         COOSA Alabama
# 19      COVINGTON     COVINGTON Alabama
# 20       CRENSHAW      CRENSHAW Alabama
# 21        CULLMAN       CULLMAN Alabama
# 22           DALE          DALE Alabama
# 23         DALLAS        DALLAS Alabama
# 24         DEKALB        DEKALB Alabama
# 25         ELMORE        ELMORE Alabama
# 26       ESCAMBIA      ESCAMBIA Alabama
# 27         ETOWAH        ETOWAH Alabama
# 28        FAYETTE       FAYETTE Alabama
# 29       FRANKLIN      FRANKLIN Alabama
# ...           ...                   ...
# 3112     WASHBURN    WASHBURN Wisconsin
# 3113   WASHINGTON  WASHINGTON Wisconsin
# 3114     WAUKESHA    WAUKESHA Wisconsin
# 3115      WAUPACA     WAUPACA Wisconsin
# 3116     WAUSHARA    WAUSHARA Wisconsin
# 3117    WINNEBAGO   WINNEBAGO Wisconsin
# 3118         WOOD        WOOD Wisconsin
# 3119       ALBANY        ALBANY Wyoming
# 3120     BIG HORN      BIG HORN Wyoming
# 3121     CAMPBELL      CAMPBELL Wyoming
# 3122       CARBON        CARBON Wyoming
# 3123     CONVERSE      CONVERSE Wyoming
# 3124        CROOK         CROOK Wyoming
# 3125      FREMONT       FREMONT Wyoming
# 3126       GOSHEN        GOSHEN Wyoming
# 3127  HOT SPRINGS   HOT SPRINGS Wyoming
# 3128      JOHNSON       JOHNSON Wyoming
# 3129      LARAMIE       LARAMIE Wyoming
# 3130      LINCOLN       LINCOLN Wyoming
# 3131      NATRONA       NATRONA Wyoming
# 3132     NIOBRARA      NIOBRARA Wyoming
# 3133         PARK          PARK Wyoming
# 3134       PLATTE        PLATTE Wyoming
# 3135     SHERIDAN      SHERIDAN Wyoming
# 3136     SUBLETTE      SUBLETTE Wyoming
# 3137   SWEETWATER    SWEETWATER Wyoming
# 3138        TETON         TETON Wyoming
# 3139        UINTA         UINTA Wyoming
# 3140     WASHAKIE      WASHAKIE Wyoming
# 3141       WESTON        WESTON Wyoming
#
# [3142 rows x 6 columns]

# %%
counties['CountyState'] = counties['CountyState'].str.strip()
final
# Out:
#      Total SNAP Full State Name          Split Counties  \
# 0         14105         Alabama                 AUTAUGA
# 1         37409         Alabama                 BALDWIN
# 2         11984         Alabama                 BARBOUR
# 3          7648         Alabama                    BIBB
# 4         16461         Alabama                  BLOUNT
# 5          5629         Alabama                 BULLOCK
# 6         10171         Alabama                  BUTLER
# 7         47333         Alabama                 CALHOUN
# 8         15914         Alabama                CHAMBERS
# 9         10011         Alabama                CHEROKEE
# 10        18489         Alabama                 CHILTON
# 11         6344         Alabama                 CHOCTAW
# 12        11854         Alabama                  CLARKE
# 13         4177         Alabama                    CLAY
# 14         4805         Alabama                CLEBURNE
# 15        11586         Alabama                  COFFEE
# 16        17488         Alabama                 COLBERT
# 17         8297         Alabama                 CONECUH
# 18         3941         Alabama                   COOSA
# 19        15241         Alabama               COVINGTON
# 20         5686         Alabama                CRENSHAW
# 21        21887         Alabama                 CULLMAN
# 22        19726         Alabama                    DALE
# 23        32665         Alabama                  DALLAS
# 24        24959         Alabama                  DEKALB
# 25        21225         Alabama                  ELMORE
# 26        18043         Alabama                ESCAMBIA
# 27        33315         Alabama                  ETOWQH
# 28         7404         Alabama                 FAYETTE
# 29        12350         Alabama                FRANKLIN
# ...         ...             ...                     ...
# 3414      12327       Wisconsin                 PORTAGE
# 3415       3730       Wisconsin                   PRICE
# 3416      57114       Wisconsin                  RACINE
# 3417       5110       Wisconsin                RICHLAND
# 3418      50776       Wisconsin                    ROCK
# 3419       5335       Wisconsin                    RUSK
# 3420      10887       Wisconsin                ST CROIX
# 3421      12835       Wisconsin                    SAUK
# 3422       6360       Wisconsin                  SAWYER
# 3423       8766       Wisconsin                 SHAWANO
# 3424      24034       Wisconsin               SHEBOYGAN
# 3425       4844       Wisconsin                  TAYLOR
# 3426       5762       Wisconsin             TREMPEALEAU
# 3427       5760       Wisconsin                  VERNON
# 3428       3744       Wisconsin                   VILAS
# 3429      21095       Wisconsin                WALWORTH
# 3430       5214       Wisconsin                WASHBURN
# 3431      28157       Wisconsin                WAUKESHA
# 3432      10141       Wisconsin                 WAUPACA
# 3433       5947       Wisconsin                WAUSHARA
# 3434      30220       Wisconsin               WINNEBAGO
# 3435      18757       Wisconsin                    WOOD
# 3436       4818       Wisconsin   ONEIDA TRIBAL COUNCIL
# 3437        458       Wisconsin  STOCKBRIDGE-MUNSEE TRI
# 3438       1215       Wisconsin  RED CLIFF TRIBAL COUNC
# 3439       1078       Wisconsin  BAD RIVER TRIBAL COUNC
# 3440       2718       Wisconsin  LAC DU FLAMBEAU TRIBAL
# 3441        458       Wisconsin  SOKAOGON TRIBAL AGENCY
# 3442        144       Wisconsin        POTAWATOMI TRIBE
# 3443      69813         Wyoming         WYOMING SD PASS
#
#                            CountyState
# 0                      AUTAUGA Alabama
# 1                      BALDWIN Alabama
# 2                      BARBOUR Alabama
# 3                         BIBB Alabama
# 4                       BLOUNT Alabama
# 5                      BULLOCK Alabama
# 6                       BUTLER Alabama
# 7                      CALHOUN Alabama
# 8                     CHAMBERS Alabama
# 9                     CHEROKEE Alabama
# 10                     CHILTON Alabama
# 11                     CHOCTAW Alabama
# 12                      CLARKE Alabama
# 13                        CLAY Alabama
# 14                    CLEBURNE Alabama
# 15                      COFFEE Alabama
# 16                     COLBERT Alabama
# 17                     CONECUH Alabama
# 18                       COOSA Alabama
# 19                   COVINGTON Alabama
# 20                    CRENSHAW Alabama
# 21                     CULLMAN Alabama
# 22                        DALE Alabama
# 23                      DALLAS Alabama
# 24                      DEKALB Alabama
# 25                      ELMORE Alabama
# 26                    ESCAMBIA Alabama
# 27                      ETOWQH Alabama
# 28                     FAYETTE Alabama
# 29                    FRANKLIN Alabama
# ...                                ...
# 3414                 PORTAGE Wisconsin
# 3415                   PRICE Wisconsin
# 3416                  RACINE Wisconsin
# 3417                RICHLAND Wisconsin
# 3418                    ROCK Wisconsin
# 3419                    RUSK Wisconsin
# 3420                ST CROIX Wisconsin
# 3421                    SAUK Wisconsin
# 3422                  SAWYER Wisconsin
# 3423                 SHAWANO Wisconsin
# 3424               SHEBOYGAN Wisconsin
# 3425                  TAYLOR Wisconsin
# 3426             TREMPEALEAU Wisconsin
# 3427                  VERNON Wisconsin
# 3428                   VILAS Wisconsin
# 3429                WALWORTH Wisconsin
# 3430                WASHBURN Wisconsin
# 3431                WAUKESHA Wisconsin
# 3432                 WAUPACA Wisconsin
# 3433                WAUSHARA Wisconsin
# 3434               WINNEBAGO Wisconsin
# 3435                    WOOD Wisconsin
# 3436   ONEIDA TRIBAL COUNCIL Wisconsin
# 3437  STOCKBRIDGE-MUNSEE TRI Wisconsin
# 3438  RED CLIFF TRIBAL COUNC Wisconsin
# 3439  BAD RIVER TRIBAL COUNC Wisconsin
# 3440  LAC DU FLAMBEAU TRIBAL Wisconsin
# 3441  SOKAOGON TRIBAL AGENCY Wisconsin
# 3442        POTAWATOMI TRIBE Wisconsin
# 3443           WYOMING SD PASS Wyoming
#
# [3444 rows x 4 columns]

# %%
df = final.merge(counties, left_on='CountyState',right_on='CountyState')

# %%
df
# Out:
#      Total SNAP Full State Name Split Counties            CountyState  \
# 0         14105         Alabama        AUTAUGA        AUTAUGA Alabama
# 1         37409         Alabama        BALDWIN        BALDWIN Alabama
# 2         11984         Alabama        BARBOUR        BARBOUR Alabama
# 3          7648         Alabama           BIBB           BIBB Alabama
# 4         16461         Alabama         BLOUNT         BLOUNT Alabama
# 5          5629         Alabama        BULLOCK        BULLOCK Alabama
# 6         10171         Alabama         BUTLER         BUTLER Alabama
# 7         47333         Alabama        CALHOUN        CALHOUN Alabama
# 8         15914         Alabama       CHAMBERS       CHAMBERS Alabama
# 9         10011         Alabama       CHEROKEE       CHEROKEE Alabama
# 10        18489         Alabama        CHILTON        CHILTON Alabama
# 11         6344         Alabama        CHOCTAW        CHOCTAW Alabama
# 12        11854         Alabama         CLARKE         CLARKE Alabama
# 13         4177         Alabama           CLAY           CLAY Alabama
# 14         4805         Alabama       CLEBURNE       CLEBURNE Alabama
# 15        11586         Alabama         COFFEE         COFFEE Alabama
# 16        17488         Alabama        COLBERT        COLBERT Alabama
# 17         8297         Alabama        CONECUH        CONECUH Alabama
# 18         3941         Alabama          COOSA          COOSA Alabama
# 19        15241         Alabama      COVINGTON      COVINGTON Alabama
# 20         5686         Alabama       CRENSHAW       CRENSHAW Alabama
# 21        21887         Alabama        CULLMAN        CULLMAN Alabama
# 22        19726         Alabama           DALE           DALE Alabama
# 23        32665         Alabama         DALLAS         DALLAS Alabama
# 24        24959         Alabama         DEKALB         DEKALB Alabama
# 25        21225         Alabama         ELMORE         ELMORE Alabama
# 26        18043         Alabama       ESCAMBIA       ESCAMBIA Alabama
# 27         7404         Alabama        FAYETTE        FAYETTE Alabama
# 4          BLOUNT
# 5         BULLOCK
# 6          BUTLER
# 7         CALHOUN
# 8        CHAMBERS
# 9        CHEROKEE
# 10        CHILTON
# 11        CHOCTAW
# 12         CLARKE
# 13           CLAY
# 14       CLEBURNE
# 15         COFFEE
# 16        COLBERT
# 17        CONECUH
# 18          COOSA
# 19      COVINGTON
# 20       CRENSHAW
# 21        CULLMAN
# 22           DALE
# 23         DALLAS
# 24         DEKALB
# 25         ELMORE
# 26       ESCAMBIA
# 27        FAYETTE
# 28       FRANKLIN
# 29         GENEVA
# ...           ...
# 2553     MARATHON
# 2554    MARINETTE
# 2555    MILWAUKEE
# 2556       OCONTO
# 2557       ONEIDA
# 2558    OUTAGAMIE
# 2559        PEPIN
# 2560       PIERCE
# 2561         POLK
# 2562      PORTAGE
# 2563        PRICE
# 2564       RACINE
# 2565     RICHLAND
# 2566         ROCK
# 2567         RUSK
# 2568         SAUK
# 2569       SAWYER
# 2570      SHAWANO
# 2571    SHEBOYGAN
# 2572       TAYLOR
# 2573  TREMPEALEAU
# 2574       VERNON
# 2575        VILAS
# 2576     WALWORTH
# 2577     WASHBURN
# 2578     WAUKESHA
# 2579      WAUPACA
# 2580     WAUSHARA
# 2581    WINNEBAGO
# 2582         WOOD
#
# [2583 rows x 9 columns]

# %%
# importing/cleaning life expectancy csv in order to get list of counties we're working with

# counties = pd.read_csv('/Users/flatironschool/Flatiron_Projects/life-expectancy/new_copy_of_repo/module_two_project/csv_files/life_expectancy_data_county.csv', header=None)
# counties = counties.rename(columns={0:'Counties', 1:'State', 2: 'Life Expectancy'})
# counties = counties.drop(counties.index[0])

# # turning all county names in county dataframe uppercase so that they match the SNAP dataframe for easier pairing
# counties['Uppercase Counties'] = [i.upper() for i in counties['Counties']]

# # resetting index to start at 0
# counties = counties.reset_index(drop=True)

# # looping through SNAP dataframe and creating list of all full county names from counties dataframe
# counties_list = []
# for i in range(0,len(final['Split Counties'])):
#     if i in counties['Uppercase Counties']:
#         counties_list.append(counties['Counties'][i])
#     else:
#         print(counties['Counties'][i])
#         counties_list.append('False')


# # making new column in SNAP dataframe for full county names, which I took from the counties dataframe via the for-loop above
# final['Proper Counties'] = counties_list

# # dropping Split Counties column from SNAP dataframe
# final = final.drop(columns=['Split Counties'])


# FOR SOME REASON THERE ARE NOW NO WISCONSIN COUNTIES IN SNAP DATAFRAME EVEN THOUGH MY CODE SHOULD HAVE MATCHED MANY BETWEEN THE COUNTIES DATAFRAME AND THE SNAP DATAFRAME
## HELP HERE PLEASE ##

# %%
## OLD CODE - HAVEN'T TOUCHED ##

# %%
# making new col named 'Full States' to store full state names
# final_frame['Full States'] = states_list


# # Deleting old column names 'States'
# final_frame.drop(columns=['States'])

# # # Merging 'Counties' & 'Full States'
# final_frame['CountyState'] = final_frame['Counties'].map(str) + " " + final_frame['Full States']


# # # Deleting old 'Counties' and 'Full States' cols
# final_final = final_frame.drop(columns=['Counties', 'Full States'])

# %%
# final_final = final_final.drop(columns=['States'])

# %%
# final_final.to_csv('csv_files/food_stamps_FINAL.csv', encoding='utf-8', index=False)

# %%
# final_final
