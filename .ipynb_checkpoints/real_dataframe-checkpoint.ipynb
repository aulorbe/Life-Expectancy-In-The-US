# %% [markdown]
# # Make the dataframe to run Regressions on

# %%
#import modules
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data with County and States together

# %%
df_wage = pd.read_csv('csv_files/wage_data_state.csv')
df_smoke = pd.read_csv('csv_files/smoking_FINAL.csv')
df_life = pd.read_csv('csv_files/life_expectancy_data_county.csv')
df_obesity = pd.read_csv('csv_files/obesity_FINAL.csv')
df_food = pd.read_csv('csv_files/food_stamps_FINAL.csv')
df_unemployment = pd.read_csv('csv_files/unemployment_FINAL.csv')

# %%
# Clean life by state

# Doing this here because it's in a weird formate
df_life['CountyState'] = df_life['County'].map(str) + " " +df_life['State']

df_life.head()
# Out:
#            County     State  Life expectancy 2010              CountyState
# 0  Autauga County   Alabama                 75.74  Autauga County  Alabama
# 1  Baldwin County   Alabama                 77.80  Baldwin County  Alabama
# 2  Barbour County   Alabama                 75.34  Barbour County  Alabama
# 3     Bibb County   Alabama                 74.13     Bibb County  Alabama
# 4   Blount County   Alabama                 76.41   Blount County  Alabama

# %%
len(df_smoke), len(df_life), len(df_food)
# Out:
# (3127, 3142, 3136)

# %%
df_smoke.head()
# Out:
#            County  Percent Smokers  State Ab     State  \
# 0  Autauga County             25.8   Alabama   Alabama
# 1  Baldwin County             23.0   Alabama   Alabama
# 2  Barbour County             26.8   Alabama   Alabama
# 3     Bibb County             30.1   Alabama   Alabama
# 4   Blount County             27.9   Alabama   Alabama
#
#                CountyState
# 0  Autauga County  Alabama
# 1  Baldwin County  Alabama
# 2  Barbour County  Alabama
# 3     Bibb County  Alabama
# 4   Blount County  Alabama

# %%
df_life.head()
# Out:
#            County     State  Life expectancy 2010              CountyState
# 0  Autauga County   Alabama                 75.74  Autauga County  Alabama
# 1  Baldwin County   Alabama                 77.80  Baldwin County  Alabama
# 2  Barbour County   Alabama                 75.34  Barbour County  Alabama
# 3     Bibb County   Alabama                 74.13     Bibb County  Alabama
# 4   Blount County   Alabama                 76.41   Blount County  Alabama

# %%
# merging food to life and creating a final dataframe 

final_df = pd.merge(df_life, df_smoke.drop_duplicates(subset=['CountyState']), on='CountyState')
final_df.tail()
# Out:
#                County_x   State_x  Life expectancy 2010  \
# 3081  Sweetwater County   Wyoming                 77.93
# 3082       Teton County   Wyoming                 82.95
# 3083       Uinta County   Wyoming                 77.51
# 3084    Washakie County   Wyoming                 78.77
# 3085      Weston County   Wyoming                 78.64
#
#                      CountyState           County_y  Percent Smokers  \
# 3081  Sweetwater County  Wyoming  Sweetwater County             25.6
# 3082       Teton County  Wyoming       Teton County             12.7
# 3083       Uinta County  Wyoming       Uinta County             22.7
# 3084    Washakie County  Wyoming    Washakie County             22.6
# 3085      Weston County  Wyoming      Weston County             24.6
#
#       State Ab   State_y
# 3081   Wyoming   Wyoming
# 3082   Wyoming   Wyoming
# 3083   Wyoming   Wyoming
# 3084   Wyoming   Wyoming
# 3085   Wyoming   Wyoming

# %%
# clean final
final_df.rename(columns={'County_x':'County', 'State_x':'State'}, inplace=True)

final_df = final_df.drop(columns=['County_y', 'State Ab', 'State_y'])
final_df['CountyState'].dtype
# Out:
# dtype('O')

# %%
#take out extra space in final_df county state
final_df['CountyState'] = final_df['CountyState'].apply(lambda x: x.replace("  ", " "))
df_food['CountyState'] = df_food['CountyState'].apply(lambda x: x.replace("  ", " "))

# %%
final_df.tail()
# Out:
#                  County     State  Life expectancy 2010  \
# 3081  Sweetwater County   Wyoming                 77.93
# 3082       Teton County   Wyoming                 82.95
# 3083       Uinta County   Wyoming                 77.51
# 3084    Washakie County   Wyoming                 78.77
# 3085      Weston County   Wyoming                 78.64
#
#                     CountyState  Percent Smokers
# 3081  Sweetwater County Wyoming             25.6
# 3082       Teton County Wyoming             12.7
# 3083       Uinta County Wyoming             22.7
# 3084    Washakie County Wyoming             22.6
# 3085      Weston County Wyoming             24.6

# %%
# merging food to final dataframe

something = pd.merge(df_food, final_df, on='CountyState', how='left').dropna()
something.tail()
# Out:
#       Jan & July Public Assist. Participation  \
# 3095                                      197
# 3101                                      332
# 3107                                       15
# 3112                                      142
# 3122                                       87
#
#       Jan & July Non-Public Assist. Participation  \
# 3095                                        14257
# 3101                                        24483
# 3107                                         1298
# 3112                                        14238
# 3122                                        11455
#
#       Jan & July TOTAL Assist. Participation              CountyState  \
# 3095                                   14454        Rusk County Texas
# 3101                                   24815      Taylor County Texas
# 3107                                    1313  Washington County Texas
# 3112                                   14380        Wood County Texas
# 3122                                   11542     Johnson County Texas
#
#                  County   State  Life expectancy 2010  Percent Smokers
# 3095        Rusk County   Texas                 76.04             26.2
# 3101      Taylor County   Texas                 76.71             22.6
# 3107  Washington County   Texas                 78.57             20.6
# 3112        Wood County   Texas                 76.67             26.2
# 3122     Johnson County   Texas                 76.84             24.6

# %%
# merging obesity to final dataframe

final_w_o = pd.merge(df_obesity, something, on='CountyState', how='left').dropna()
final_w_o.tail()
# Out:
#      Percent Obese                     CountyState  \
# 2866          9447               Wood County Texas
# 2973         19155      Montgomery County Virginia
# 2977          2993  Northumberland County Virginia
# 2979          8220          Orange County Virginia
# 3169         19847      Jefferson County Wisconsin
#
#       Jan & July Public Assist. Participation  \
# 2866                                    142.0
# 2973                                   3240.0
# 2977                                   2180.0
# 2979                                   3001.0
# 3169                                    502.0
#
#       Jan & July Non-Public Assist. Participation  \
# 2866                                      14238.0
# 2973                                       7444.0
# 2977                                       9979.0
# 2979                                       8868.0
# 3169                                       6167.0
#
#       Jan & July TOTAL Assist. Participation                 County  \
# 2866                                 14380.0            Wood County
# 2973                                 10684.0      Montgomery County
# 2977                                 12159.0  Northumberland County
# 2979                                 11869.0          Orange County
# 3169                                  6669.0       Jefferson County
#
#            State  Life expectancy 2010  Percent Smokers
# 2866       Texas                 76.67             26.2
# 2973    Virginia                 79.12             18.1
# 2977    Virginia                 79.25             22.9
# 2979    Virginia                 78.69             23.0
# 3169   Wisconsin                 80.20             22.3

# %%
# merging unemployment to final dataframe

final_w_un = pd.merge(df_unemployment, final_w_o, on='CountyState', how='left').dropna()
final_w_un.tail()
# Out:
#       Unemployment_rate_2010                     CountyState Percent Obese  \
# 2857                     9.1               Wood County Texas          9447
# 2964                     7.1      Montgomery County Virginia         19155
# 2968                     8.7  Northumberland County Virginia          2993
# 2970                     8.3          Orange County Virginia          8220
# 3159                     8.7      Jefferson County Wisconsin         19847
#
#       Jan & July Public Assist. Participation  \
# 2857                                    142.0
# 2964                                   3240.0
# 2968                                   2180.0
# 2970                                   3001.0
# 3159                                    502.0
#
#       Jan & July Non-Public Assist. Participation  \
# 2857                                      14238.0
# 2964                                       7444.0
# 2968                                       9979.0
# 2970                                       8868.0
# 3159                                       6167.0
#
#       Jan & July TOTAL Assist. Participation                 County  \
# 2857                                 14380.0            Wood County
# 2964                                 10684.0      Montgomery County
# 2968                                 12159.0  Northumberland County
# 2970                                 11869.0          Orange County
# 3159                                  6669.0       Jefferson County
#
#            State  Life expectancy 2010  Percent Smokers
# 2857       Texas                 76.67             26.2
# 2964    Virginia                 79.12             18.1
# 2968    Virginia                 79.25             22.9
# 2970    Virginia                 78.69             23.0
# 3159   Wisconsin                 80.20             22.3

# %%
final_w_un['State'] = final_w_un['State'].apply(lambda x: x.replace(" ", ""))

# %%
df_wage['State'] = df_wage['State'].apply(lambda x: x.replace(" ", ""))

final_w_un.tail()
# Out:
#       Unemployment_rate_2010                     CountyState Percent Obese  \
# 2857                     9.1               Wood County Texas          9447
# 2964                     7.1      Montgomery County Virginia         19155
# 2968                     8.7  Northumberland County Virginia          2993
# 2970                     8.3          Orange County Virginia          8220
# 3159                     8.7      Jefferson County Wisconsin         19847
#
#       Jan & July Public Assist. Participation  \
# 2857                                    142.0
# 2964                                   3240.0
# 2968                                   2180.0
# 2970                                   3001.0
# 3159                                    502.0
#
#       Jan & July Non-Public Assist. Participation  \
# 2857                                      14238.0
# 2964                                       7444.0
# 2968                                       9979.0
# 2970                                       8868.0
# 3159                                       6167.0
#
#       Jan & July TOTAL Assist. Participation                 County  \
# 2857                                 14380.0            Wood County
# 2964                                 10684.0      Montgomery County
# 2968                                 12159.0  Northumberland County
# 2970                                 11869.0          Orange County
# 3159                                  6669.0       Jefferson County
#
#           State  Life expectancy 2010  Percent Smokers
# 2857      Texas                 76.67             26.2
# 2964   Virginia                 79.12             18.1
# 2968   Virginia                 79.25             22.9
# 2970   Virginia                 78.69             23.0
# 3159  Wisconsin                 80.20             22.3

# %%
# last to add min wage by state, not county
# last to add min wage by state, not countydf_ow = df_obesity.merge(df_wage, on=['State'], how='outer')

# final = final_w_un.merge(df_wage, on=['State'], how='left')
# final.head()


final = pd.merge(final_w_un, df_wage, on='State', how='left').dropna()
final.tail()

#df_wage
# Out:
#      Unemployment_rate_2010                     CountyState Percent Obese  \
# 551                     9.1               Wood County Texas          9447
# 552                     7.1      Montgomery County Virginia         19155
# 553                     8.7  Northumberland County Virginia          2993
# 554                     8.3          Orange County Virginia          8220
# 555                     8.7      Jefferson County Wisconsin         19847
#
#      Jan & July Public Assist. Participation  \
# 551                                    142.0
# 552                                   3240.0
# 553                                   2180.0
# 554                                   3001.0
# 555                                    502.0
#
#      Jan & July Non-Public Assist. Participation  \
# 551                                      14238.0
# 552                                       7444.0
# 553                                       9979.0
# 554                                       8868.0
# 555                                       6167.0
#
#      Jan & July TOTAL Assist. Participation                 County      State  \
# 551                                 14380.0            Wood County      Texas
# 552                                 10684.0      Montgomery County   Virginia
# 553                                 12159.0  Northumberland County   Virginia
# 554                                 11869.0          Orange County   Virginia
# 555                                  6669.0       Jefferson County  Wisconsin
#
#      Life expectancy 2010  Percent Smokers  Min Wage
# 551                 76.67             26.2      7.25
# 552                 79.12             18.1      7.25
# 553                 79.25             22.9      7.25
# 554                 78.69             23.0      7.25
# 555                 80.20             22.3      7.25

# %%
# Out:
# State       Alabama
# Min Wage       7.25
# Name: 0, dtype: object
