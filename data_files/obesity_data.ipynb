# %%
#import modules
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/Users/flatironschool/Downloads/Obesity.xlsx')

# %%
df.head()
# Out:
#   Obesity Prevalence  Unnamed: 1      Unnamed: 2    2004 Unnamed: 4  \
# 0              State  FIPS Codes          County  number    percent
# 1            Alabama       01001  Autauga County   10180       30.2
# 2            Alabama       01003  Baldwin County   30120       25.7
# 3            Alabama       01005  Barbour County    6645       31.7
# 4            Alabama       01007     Bibb County    4605       29.3
#
#                Unnamed: 5              Unnamed: 6            Unnamed: 7  \
# 0  lower confidence limit  upper confidence limit  age-adjusted percent
# 1                    24.7                    36.5                  29.8
# 2                    21.7                    30.3                  25.9
# 3                      26                    38.1                  31.6
# 4                    23.4                    36.1                  29.2
#
#                             Unnamed: 8                           Unnamed: 9  \
# ...

# %%
# get the State, County an and Obesity
df = df.iloc[:,[0,2,46]].dropna()
df.head()
# Out:
#   Obesity Prevalence      Unnamed: 2 Unnamed: 46
# 0              State          County     percent
# 1            Alabama  Autauga County        30.5
# 2            Alabama  Baldwin County        26.6
# 3            Alabama  Barbour County        37.3
# 4            Alabama     Bibb County        34.3

# %%
# renaming cols
df.columns = ['State', 'County', 'Percent Obese']
df.head()
# Out:
#      State          County Percent Obese
# 0    State          County       percent
# 1  Alabama  Autauga County          30.5
# 2  Alabama  Baldwin County          26.6
# 3  Alabama  Barbour County          37.3
# 4  Alabama     Bibb County          34.3

# %%
# dropping first row
dropped = df.drop(df.index[0]).reset_index(drop=True)

dropped
# Out:
#             State                   County Percent Obese
# 0         Alabama           Autauga County          30.5
# 1         Alabama           Baldwin County          26.6
# 2         Alabama           Barbour County          37.3
# 3         Alabama              Bibb County          34.3
# 4         Alabama            Blount County          30.4
# 5         Alabama           Bullock County          42.1
# 6         Alabama            Butler County          38.3
# 7         Alabama           Calhoun County          33.2
# 8         Alabama          Chambers County          35.4
# 9         Alabama          Cherokee County          31.4
# 10        Alabama           Chilton County          38.3
# 11        Alabama           Choctaw County          38.9
# 12        Alabama            Clarke County            36
# 13        Alabama              Clay County          35.3
# 14        Alabama          Cleburne County          31.3
# ...

# %%
# dropping PR rows
new = dropped[dropped.State != 'Puerto Rico']
new
# Out:
#           State              County Percent Obese
# 0       Alabama      Autauga County          30.5
# 1       Alabama      Baldwin County          26.6
# 2       Alabama      Barbour County          37.3
# 3       Alabama         Bibb County          34.3
# 4       Alabama       Blount County          30.4
# 5       Alabama      Bullock County          42.1
# 6       Alabama       Butler County          38.3
# 7       Alabama      Calhoun County          33.2
# 8       Alabama     Chambers County          35.4
# 9       Alabama     Cherokee County          31.4
# 10      Alabama      Chilton County          38.3
# 11      Alabama      Choctaw County          38.9
# 12      Alabama       Clarke County            36
# 13      Alabama         Clay County          35.3
# 14      Alabama     Cleburne County          31.3
# 15      Alabama       Coffee County          29.9
# 16      Alabama      Colbert County          32.2
# 17      Alabama      Conecuh County          36.3
# ...

# %%
# Merging State & County in 'CountyState' col
new['CountyState'] = new['County'].map(str) + " " + new['State']
# Out:
# /Users/flatironschool/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Dropping 'State' and 'County'
final = new.drop(columns=['State', 'County'])
final
# Out:
#      Percent Obese                  CountyState
# 0             30.5       Autauga County Alabama
# 1             26.6       Baldwin County Alabama
# 2             37.3       Barbour County Alabama
# 3             34.3          Bibb County Alabama
# 4             30.4        Blount County Alabama
# 5             42.1       Bullock County Alabama
# 6             38.3        Butler County Alabama
# 7             33.2       Calhoun County Alabama
# 8             35.4      Chambers County Alabama
# 9             31.4      Cherokee County Alabama
# 10            38.3       Chilton County Alabama
# 11            38.9       Choctaw County Alabama
# 12              36        Clarke County Alabama
# 13            35.3          Clay County Alabama
# 14            31.3      Cleburne County Alabama
# 15            29.9        Coffee County Alabama
# 16            32.2       Colbert County Alabama
# 17            36.3       Conecuh County Alabama
# 18            34.3         Coosa County Alabama
# ...

# %%
final.to_csv('csv_files/obesity_FINAL.csv', encoding='utf-8', index=False)
