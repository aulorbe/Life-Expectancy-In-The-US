# %%
import pandas as pd

df = pd.read_excel('/Users/flatironschool/Downloads/Poverty_Income.xls', header=None)[2:]

# %%
df
# Out:
#                                                      0            1       2   \
# 2                                            State FIPS  County FIPS  Postal
# 3                                                    00            0      US
# 4                                                    01            0      AL
# 5                                                    01            1      AL
# 6                                                    01            3      AL
# 7                                                    01            5      AL
# 8                                                    01            7      AL
# 9                                                    01            9      AL
# 10                                                   01           11      AL
# 11                                                   01           13      AL
# 12                                                   01           15      AL
# ...

# %%
df.columns=df.iloc[0]
df
# Out:
# 2                                            State FIPS  County FIPS  Postal  \
# 2                                            State FIPS  County FIPS  Postal
# 3                                                    00            0      US
# 4                                                    01            0      AL
# 5                                                    01            1      AL
# 6                                                    01            3      AL
# 7                                                    01            5      AL
# 8                                                    01            7      AL
# 9                                                    01            9      AL
# 10                                                   01           11      AL
# 11                                                   01           13      AL
# 12                                                   01           15      AL
# ...

# %%
indexed = df.reset_index()

# %%
drop_second_row = indexed.drop(indexed.index[0])

drop_second_row
# Out:
# 2     index                                         State FIPS County FIPS  \
# 1         3                                                 00           0
# 2         4                                                 01           0
# 3         5                                                 01           1
# 4         6                                                 01           3
# 5         7                                                 01           5
# 6         8                                                 01           7
# 7         9                                                 01           9
# 8        10                                                 01          11
# 9        11                                                 01          13
# 10       12                                                 01          15
# 11       13                                                 01          17
# ...

# %%
only_needed_cols = drop_second_row[['Name', 'Poverty Estimate All Ages', 'Poverty Percent All Ages' ]]

# %%
only_needed_cols

print(something)
# Out:
# 2
# State FIPS                                          State FIPS
# County FIPS                                        County FIPS
# Postal                                                  Postal
# Name                                                      Name
# Poverty Estimate All Ages            Poverty Estimate All Ages
# 90% CI Lower Bound                          90% CI Lower Bound
# 90% CI Upper Bound                          90% CI Upper Bound
# Poverty Percent All Ages              Poverty Percent All Ages
# 90% CI Lower Bound                          90% CI Lower Bound
# 90% CI Upper Bound                          90% CI Upper Bound
# Poverty Estimate Under Age 18    Poverty Estimate Under Age 18
# 90% CI Lower Bound                          90% CI Lower Bound
# 90% CI Upper Bound                          90% CI Upper Bound
# Poverty Percent Under Age 18      Poverty Percent Under Age 18
# 90% CI Lower Bound                          90% CI Lower Bound
# ...
